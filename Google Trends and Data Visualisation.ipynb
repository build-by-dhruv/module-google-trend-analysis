# %% [markdown]
# # Introduction

# %% [markdown]
# Google Trends gives us an estimate of search volume. Let's explore if search popularity relates to other kinds of data. Perhaps there are patterns in Google's search volume and the price of Bitcoin or a hot stock like Tesla. Perhaps search volume for the term "Unemployment Benefits" can tell us something about the actual unemployment rate?
#
# Data Sources: <br>
#
# <ul>
# <li> <a href="https://fred.stlouisfed.org/series/UNRATE/">Unemployment Rate from FRED</a></li>
# <li> <a href="https://trends.google.com/trends/explore">Google Trends</a> </li>
# <li> <a href="https://finance.yahoo.com/quote/TSLA/history?p=TSLA">Yahoo Finance for Tesla Stock Price</a> </li>
# <li> <a href="https://finance.yahoo.com/quote/BTC-USD/history?p=BTC-USD">Yahoo Finance for Bitcoin Stock Price</a> </li>
# </ul>

# %% [markdown]
# # Import Statements

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Read the Data
#
# Download and add the .csv files to the same folder as your notebook.

# %%
df_tesla = pd.read_csv('TESLA Search Trend vs Price.csv')

df_btc_search = pd.read_csv('Bitcoin Search Trend.csv')
df_btc_price = pd.read_csv('Daily Bitcoin Price.csv')

df_unemployment = pd.read_csv('UE Benefits Search vs UE Rate 2004-19.csv')

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ### Tesla

# %% [markdown]
# **Challenge**: <br>
#
# <ul>
# <li>What are the shapes of the dataframes? </li>
# <li>How many rows and columns? </li>
# <li>What are the column names? </li>
# <li>Complete the f-string to show the largest/smallest number in the search data column</li>
# <li>Try the <code>.describe()</code> function to see some useful descriptive statistics</li>
# <li>What is the periodicity of the time series data (daily, weekly, monthly)? </li>
# <li>What does a value of 100 in the Google Trend search popularity actually mean?</li>
# </ul>

# %%
df_tesla.head()
# Out:
#         MONTH  TSLA_WEB_SEARCH  TSLA_USD_CLOSE
# 0  2010-06-01                3           4.766
# 1  2010-07-01                3           3.988
# 2  2010-08-01                2           3.896
# 3  2010-09-01                2           4.082
# 4  2010-10-01                2           4.368

# %%
print(df_tesla.shape)
# Out:
# (124, 3)

# %%
print(f'rows: {df_tesla.shape[0]} \ncolumns: {df_tesla.shape[1]}')
# Out:
# rows: 124
# columns: 3

# %%
print(df_tesla.columns)
# Out:
# Index(['MONTH', 'TSLA_WEB_SEARCH', 'TSLA_USD_CLOSE'], dtype='object')

# %%
print(f'Largest value for Tesla in Web Search: ',df_tesla.TSLA_WEB_SEARCH.max())
print(f'Smallest value for Tesla in Web Search: ',df_tesla.TSLA_WEB_SEARCH.min())
# Out:
# Largest value for Tesla in Web Search:  31
# Smallest value for Tesla in Web Search:  2

# %%
df_tesla.describe()
# Out:
#        TSLA_WEB_SEARCH  TSLA_USD_CLOSE
# count       124.000000      124.000000
# mean          8.725806       50.962145
# std           5.870332       65.908389
# min           2.000000        3.896000
# 25%           3.750000        7.352500
# 50%           8.000000       44.653000
# 75%          12.000000       58.991999
# max          31.000000      498.320007

# %%
df_tesla['MONTH'] = pd.to_datetime(df_tesla['MONTH'])

# %%
df_tesla = df_tesla.sort_values(by='MONTH')

# %%
df_tesla['Time Differece'] = df_tesla['MONTH'].diff()

# %%
df_tesla.head()
# Out:
#        MONTH  TSLA_WEB_SEARCH  TSLA_USD_CLOSE Time Differece
# 0 2010-06-01                3           4.766            NaT
# 1 2010-07-01                3           3.988        30 days
# 2 2010-08-01                2           3.896        31 days
# 3 2010-09-01                2           4.082        31 days
# 4 2010-10-01                2           4.368        30 days

# %% [markdown]
# ### Unemployment Data

# %%
df_unemployment.head()
# Out:
#      MONTH  UE_BENEFITS_WEB_SEARCH  UNRATE
# 0  2004-01                      34     5.7
# 1  2004-02                      33     5.6
# 2  2004-03                      25     5.8
# 3  2004-04                      29     5.6
# 4  2004-05                      23     5.6

# %%
df_unemployment.shape
# Out:
# (181, 3)

# %%
df_unemployment.describe()
# Out:
#        UE_BENEFITS_WEB_SEARCH      UNRATE
# count              181.000000  181.000000
# mean                35.110497    6.217680
# std                 20.484925    1.891859
# min                 14.000000    3.700000
# 25%                 21.000000    4.700000
# 50%                 26.000000    5.400000
# 75%                 45.000000    7.800000
# max                100.000000   10.000000

# %%
df_unemployment.MONTH = pd.to_datetime(df_unemployment.MONTH)

# %%
df_unemployment.sort_values(by="MONTH" , inplace=True)

# %%
df_unemployment['Time difference '] = df_unemployment['MONTH'].diff()

# %%
df_unemployment.head()
# Out:
#        MONTH  UE_BENEFITS_WEB_SEARCH  UNRATE Time difference
# 0 2004-01-01                      34     5.7              NaT
# 1 2004-02-01                      33     5.6          31 days
# 2 2004-03-01                      25     5.8          29 days
# 3 2004-04-01                      29     5.6          31 days
# 4 2004-05-01                      23     5.6          30 days

# %%
print('Largest value for "Unemployemnt Benefits" '
      f'in Web Search: ' , df_unemployment.UE_BENEFITS_WEB_SEARCH.max())
# Out:
# Largest value for "Unemployemnt Benefits" in Web Search:  100

# %% [markdown]
# ### Bitcoin

# %%
df_btc_search.head()
# Out:
#      MONTH  BTC_NEWS_SEARCH
# 0  2014-09                5
# 1  2014-10                4
# 2  2014-11                4
# 3  2014-12                4
# 4  2015-01                5

# %%
print(f'largest BTC News Search: ' , df_btc_search.BTC_NEWS_SEARCH.max())
# Out:
# largest BTC News Search:  100

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Check for Missing Values

# %% [markdown]
# **Challenge**: Are there any missing values in any of the dataframes? If so, which row/rows have missing values? How many missing values are there?

# %%
# Out:
# True

# %%
print(f'Missing values for Tesla?: ' , df_tesla.isna().values.any())

print(f'Missing values for U/E?: ' , df_unemployment.isna().values.any())
print(f'Missing values for BTC Search?: ' , df_btc_search.isna().values.any())
# Out:
# Missing values for Tesla?:  False
# Missing values for U/E?:  True
# Missing values for BTC Search?:  False

# %%
print(f'Missing values for BTC price?: ' , df_btc_price.isna().values.any())
df_btc_price[df_btc_price.VOLUME.isna()]
# Out:
# Missing values for BTC price?:  True
#             DATE  CLOSE  VOLUME
# 2148  2020-08-04    NaN     NaN

# %%
print(f'Number of missing values: ',df_btc_price.isna().values.sum())
# Out:
# Number of missing values:  2

# %% [markdown]
# **Challenge**: Remove any missing values that you found.

# %%
df_btc_price.dropna(inplace=True)
# df_btc_price.shape

# %% [markdown]
# ### Convert Strings to DateTime Objects

# %% [markdown]
# **Challenge**: Check the data type of the entries in the DataFrame MONTH or DATE columns. Convert any strings in to Datetime objects. Do this for all 4 DataFrames. Double check if your type conversion was successful.

# %%
df_tesla = pd.read_csv('TESLA Search Trend vs Price.csv')

df_btc_search = pd.read_csv('Bitcoin Search Trend.csv')
df_btc_price = pd.read_csv('Daily Bitcoin Price.csv')

df_unemployment = pd.read_csv('UE Benefits Search vs UE Rate 2004-19.csv')
df_unemployment_new = pd.read_csv('UE Benefits Search vs UE Rate 2004-20.csv')

# %%
df_tesla.MONTH = pd.to_datetime(df_tesla.MONTH )
df_btc_price.DATE = pd.to_datetime(df_btc_price.DATE )
df_btc_search.MONTH = pd.to_datetime( df_btc_search.MONTH)
df_unemployment.MONTH = pd.to_datetime( df_unemployment.MONTH)
df_unemployment_new.MONTH = pd.to_datetime( df_unemployment_new.MONTH)

# %% [markdown]
# ### Converting from Daily to Monthly Data
#
# [Pandas .resample() documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.resample.html) <br>

# %%
df_btc_monthly_price  = df_btc_price.resample('M' , on = 'DATE').last()

# %%
df_btc_monthly_price.head()
# Out:
#                  CLOSE      VOLUME
# DATE
# 2014-09-30  386.944000  34707300.0
# 2014-10-31  338.321014  12545400.0
# 2014-11-30  378.046997   9194440.0
# 2014-12-31  320.192993  13942900.0
# 2015-01-31  217.464005  23348200.0

# %%
df_btc_monthly_price.shape
# Out:
# (73, 2)

# %% [markdown]
# # Data Visualisation

# %% [markdown]
# ### Notebook Formatting & Style Helpers

# %%
# Create locators for ticks on the time axis

# %%
# Register date converters to avoid warning messages

# %% [markdown]
# ### Tesla Stock Price v.s. Search Volume

# %% [markdown]
# **Challenge:** Plot the Tesla stock price against the Tesla search volume using a line chart and two different axes. Label one axis 'TSLA Stock Price' and the other 'Search Trend'.

# %%
# used to get current axis
axis_1  = plt.gca()

# used to share  the same x axis but y axis on different side 
axis_2   = plt.twinx()
axis_1.plot(df_tesla['MONTH'] ,df_tesla['TSLA_USD_CLOSE']  )
axis_2.plot(df_tesla['MONTH'] ,df_tesla['TSLA_WEB_SEARCH']  )
axis_1.set_xlabel('check')
axis_1.set_ylabel('Stock price')
axis_2.set_ylabel('Web search traffic')
# Out:
# Text(0, 0.5, 'Web search traffic')

# %% [markdown]
# **Challenge**: Add colours to style the chart. This will help differentiate the two lines and the axis labels. Try using one of the blue [colour names](https://matplotlib.org/3.1.1/gallery/color/named_colors.html) for the search volume and a HEX code for a red colour for the stock price.
# <br>
# <br>
# Hint: you can colour both the [axis labels](https://matplotlib.org/3.3.2/api/text_api.html#matplotlib.text.Text) and the [lines](https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.lines.Line2D.html#matplotlib.lines.Line2D) on the chart using keyword arguments (kwargs).

# %%
# used to get current axis
axis_1  = plt.gca()

# used to share  the same x axis but y axis on different side 
axis_2   = plt.twinx()
axis_1.plot(df_tesla['MONTH'] ,df_tesla['TSLA_USD_CLOSE']  , color = '#FFFF00')
axis_2.plot(df_tesla['MONTH'] ,df_tesla['TSLA_WEB_SEARCH'] , 'r' )
axis_1.set_xlabel('check')
axis_1.set_ylabel('Stock price' )
axis_2.set_ylabel('Web search traffic' , color = 'r')
# Out:
# Text(0, 0.5, 'Web search traffic')

# %% [markdown]
# **Challenge**: Make the chart larger and easier to read.
#
# 1. Increase the figure size (e.g., to 14 by 8).
# 2. Increase the font sizes for the labels and the ticks on the x-axis to 14.
# 3. Rotate the text on the x-axis by 45 degrees.
# 4. Make the lines on the chart thicker.
# 5. Add a title that reads 'Tesla Web Search vs Price'
# 6. Keep the chart looking sharp by changing the dots-per-inch or [DPI value](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.figure.html).
# 7. Set minimum and maximum values for the y and x axis. Hint: check out methods like [set_xlim()](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.axes.Axes.set_xlim.html).
# 8. Finally use [plt.show()](https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.show.html) to display the chart below the cell instead of relying on the automatic notebook output.

# %%
import matplotlib.pyplot as plt

# Create a figure with a specified DPI
plt.figure(figsize=(10, 5), dpi=100)  # Width=10 inches, Height=5 inches, DPI=100

# Used to get the current axis
axis_1 = plt.gca()

# Set the x-axis tick labels with rotation
plt.xticks(rotation=45)

# Used to share the same x-axis but y-axis on different side
axis_2 = plt.twinx()

# Your data and plotting code
axis_1.plot(df_tesla['MONTH'], df_tesla['TSLA_USD_CLOSE'], color='#FFFF00', linewidth=5)
axis_2.plot(df_tesla['MONTH'], df_tesla['TSLA_WEB_SEARCH'], 'r', linewidth=5)

# Set the x-axis limits
axis_1.set_xlim(df_tesla['MONTH'].min(), df_tesla['MONTH'].max())  # Set x-axis limits based on data

# Set the y-axis limits for axis_1
axis_1.set_ylim(0, df_tesla['TSLA_USD_CLOSE'].max() + 10)  # Adjust the maximum value if needed

# Set the y-axis limits for axis_2 (if necessary)
axis_2.set_ylim(0, df_tesla['TSLA_WEB_SEARCH'].max() + 10)  # Adjust the maximum value if needed

# Set labels and title
axis_1.set_xlabel('Year', fontsize=14)
axis_1.set_ylabel('Stock price', fontsize=14)
axis_2.set_ylabel('Web search traffic', color='r', fontsize=14)

# Add a title to the plot
plt.title("Tesla Web Search vs Price", fontsize=16)

# Show the plot
plt.show()

# %% [markdown]
# How to add tick formatting for dates on the x-axis.

# %%
import matplotlib.pyplot as plt

# Create a figure with a specified DPI
plt.figure(figsize=(10, 5), dpi=100)  # Width=10 inches, Height=5 inches, DPI=100

# Used to get the current axis
axis_1 = plt.gca()

# Set the x-axis tick labels with rotation
plt.xticks(rotation=45)

# Used to share the same x-axis but y-axis on different side
axis_2 = plt.twinx()

# Your data and plotting code
axis_1.plot(df_tesla['MONTH'], df_tesla['TSLA_USD_CLOSE'], color='#FFFF00', linewidth=5)
axis_2.plot(df_tesla['MONTH'], df_tesla['TSLA_WEB_SEARCH'], 'r', linewidth=5)

# Set the x-axis limits
axis_1.set_xlim(df_tesla['MONTH'].min(), df_tesla['MONTH'].max())  # Set x-axis limits based on data

# Set the y-axis limits for axis_1
axis_1.set_ylim(0, df_tesla['TSLA_USD_CLOSE'].max() + 10)  # Adjust the maximum value if needed

# Set the y-axis limits for axis_2 (if necessary)
axis_2.set_ylim(0, df_tesla['TSLA_WEB_SEARCH'].max() + 10)  # Adjust the maximum value if needed

# Set labels and title
axis_1.set_xlabel('Year', fontsize=14)
axis_1.set_ylabel('Stock price', fontsize=14)
axis_2.set_ylabel('Web search traffic', color='r', fontsize=14)

# Add a title to the plot
plt.title("Tesla Web Search vs Price", fontsize=16)


import matplotlib.dates as mdates 

years = mdates.YearLocator()
months = mdates.MonthLocator()
years_fmt = mdates.DateFormatter('%Y')

# format the 
axis_1.xaxis.set_major_locator(years)
axis_1.xaxis.set_major_formatter(years_fmt)
axis_1.xaxis.set_minor_locator(months)

# %% [markdown]
# ### Bitcoin (BTC) Price v.s. Search Volume

# %% [markdown]
# **Challenge**: Create the same chart for the Bitcoin Prices vs. Search volumes. <br>
#
# 1. Modify the chart title to read 'Bitcoin News Search vs Resampled Price' <br>
# 2. Change the y-axis label to 'BTC Price' <br>
# 3. Change the y- and x-axis limits to improve the appearance <br>
# 4. Investigate the [linestyles](https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.plot.html) to make the BTC price a dashed line <br>
# 5. Investigate the [marker types](https://matplotlib.org/3.2.1/api/markers_api.html) to make the search datapoints little circles <br>
# 6. Were big increases in searches for Bitcoin accompanied by big increases in the price?

# %%
df_btc_search.head()
# Out:
#      MONTH  BTC_NEWS_SEARCH
# 0  2014-09                5
# 1  2014-10                4
# 2  2014-11                4
# 3  2014-12                4
# 4  2015-01                5

# %%
df_btc_price.head()
# Out:
#         DATE       CLOSE      VOLUME
# 0 2014-09-17  457.334015  21056800.0
# 1 2014-09-18  424.440002  34483200.0
# 2 2014-09-19  394.795990  37919700.0
# 3 2014-09-20  408.903992  36863600.0
# 4 2014-09-21  398.821014  26580100.0

# %%
# this is resampled data with this code 
df_btc_monthly_price  = df_btc_price.resample('M' , on = 'DATE').last()


df_btc_monthly_price.head()
# Out:
#                  CLOSE      VOLUME
# DATE
# 2014-09-30  386.944000  34707300.0
# 2014-10-31  338.321014  12545400.0
# 2014-11-30  378.046997   9194440.0
# 2014-12-31  320.192993  13942900.0
# 2015-01-31  217.464005  23348200.0

# %%
df_btc_monthly_price['CLOSE'][:1]
# Out:
# DATE
# 2014-09-30    386.944
# Freq: M, Name: CLOSE, dtype: float64

# %%
import matplotlib.pyplot as plt

# Create a figure with a specified DPI
plt.figure(figsize=(10, 5), dpi=100 ,)  # Width=10 inches, Height=5 inches, DPI=100

# Used to get the current axis
axis_1 = plt.gca()

# Set the x-axis tick labels with rotation
plt.xticks(rotation=45)

# Used to share the same x-axis but y-axis on different side
axis_2 = plt.twinx()

# Your data and plotting code
axis_1.plot(df_btc_monthly_price.index, df_btc_monthly_price['CLOSE'], color='#FFFF00', linewidth=2 , )
axis_2.plot(df_btc_search['MONTH'], df_btc_search['BTC_NEWS_SEARCH'], 'r', linewidth=2 ,linestyle = 'dashed' , marker='o')

# Set the x-axis limits
axis_1.set_xlim(df_btc_search['MONTH'].min(), df_btc_search['MONTH'].max())  # Set x-axis limits based on data

# Set the y-axis limits for axis_1
axis_1.set_ylim(0, df_btc_monthly_price['CLOSE'].max() + 20)  # Adjust the maximum value if needed

# Set the y-axis limits for axis_2 (if necessary)
axis_2.set_ylim(0, df_btc_search['BTC_NEWS_SEARCH'].max() + 20)  # Adjust the maximum value if needed

# Set labels and title
axis_1.set_xlabel('Year', fontsize=14)
axis_1.set_ylabel('BTC price', fontsize=14)
axis_2.set_ylabel('Web search traffic', color='r', fontsize=14)

# Add a title to the plot
plt.title("Bitcoin (BTC) Price v.s. Search Volume", fontsize=16)


import matplotlib.dates as mdates 

years = mdates.YearLocator()
months = mdates.MonthLocator()
years_fmt = mdates.DateFormatter('%Y')

# format the 
axis_1.xaxis.set_major_locator(years)
axis_1.xaxis.set_major_formatter(years_fmt)
axis_1.xaxis.set_minor_locator(months)

# %% [markdown]
# ### Unemployement Benefits Search vs. Actual Unemployment in the U.S.

# %% [markdown]
# **Challenge** Plot the search for "unemployment benefits" against the unemployment rate.
#
# 1. Change the title to: Monthly Search of "Unemployment Benefits" in the U.S. vs the U/E Rate <br>
# 2. Change the y-axis label to: FRED U/E Rate <br>
# 3. Change the axis limits <br>
# 4. Add a grey [grid](https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.grid.html) to the chart to better see the years and the U/E rate values. Use dashes for the line style<br>
# 5. Can you discern any seasonality in the searches? Is there a pattern?

# %%
import matplotlib.pyplot as plt

# Create a figure with a specified DPI
plt.figure(figsize=(10, 5) )  # Width=10 inches, Height=5 inches, DPI=100

plt.grid()
# Used to get the current axis
axis_1 = plt.gca()

# Set the x-axis tick labels with rotation
plt.xticks(rotation=45)

# Used to share the same x-axis but y-axis on different side
axis_2 = plt.twinx()


# Your data and plotting code
axis_1.plot(df_unemployment['MONTH'], df_unemployment['UE_BENEFITS_WEB_SEARCH'], color='purple', linewidth=2 , )
axis_2.plot(df_unemployment['MONTH'], df_unemployment['UNRATE'], 'r', linewidth=2 ,linestyle = 'dashed' )

# Set the x-axis limits
axis_1.set_xlim([df_unemployment['MONTH'].min(), df_unemployment['MONTH'].max()])  # Set x-axis limits based on data

# Set the y-axis limits for axis_1
# axis_1.set_ylim(0, df_unemployment['UE_BENEFITS_WEB_SEARCH'].max() + 5)  # Adjust the maximum value if needed

# Set the y-axis limits for axis_2 (if necessary)
# axis_2.set_ylim(0, df_unemployment['UNRATE'].max() + 5)  # Adjust the maximum value if needed

# Set labels and title
axis_1.set_xlabel('Year', fontsize=14)
axis_1.set_ylabel('UE_BENEFITS_WEB_SEARCH', fontsize=14)
axis_2.set_ylabel('Unemployment rate', color='r', fontsize=14)

# Add a title to the plot
plt.title("UE_BENEFITS_WEB_SEARCH v.s. Unemployment rate", fontsize=16)


import matplotlib.dates as mdates 

years = mdates.YearLocator()
months = mdates.MonthLocator()
years_fmt = mdates.DateFormatter('%Y')

# format the 
axis_1.xaxis.set_major_locator(years)
axis_1.xaxis.set_major_formatter(years_fmt)
axis_1.xaxis.set_minor_locator(months)

# %% [markdown]
# **Challenge**: Calculate the 3-month or 6-month rolling average for the web searches. Plot the 6-month rolling average search data against the actual unemployment. What do you see in the chart? Which line moves first?

# %%
import matplotlib.pyplot as plt

# Create a figure with a specified DPI
plt.figure(figsize=(10, 5) )  # Width=10 inches, Height=5 inches, DPI=100

plt.grid()
# Used to get the current axis
axis_1 = plt.gca()

# Set the x-axis tick labels with rotation
plt.xticks(rotation=45)

# Used to share the same x-axis but y-axis on different side
axis_2 = plt.twinx()

# Calculate the rolling average over a 6 month window
roll_df = df_unemployment[['UE_BENEFITS_WEB_SEARCH', 'UNRATE']].rolling(window=6).mean()

# Your data and plotting code
axis_1.plot(df_unemployment['MONTH'], roll_df['UE_BENEFITS_WEB_SEARCH'], color='purple', linewidth=2 , )
axis_2.plot(df_unemployment['MONTH'], roll_df['UNRATE'], 'r', linewidth=2 ,linestyle = 'dashed' )

# Set the x-axis limits
axis_1.set_xlim([df_unemployment['MONTH'].min(), df_unemployment['MONTH'].max()])  # Set x-axis limits based on data

# Set the y-axis limits for axis_1
# axis_1.set_ylim(0, df_unemployment['UE_BENEFITS_WEB_SEARCH'].max() + 5)  # Adjust the maximum value if needed

# Set the y-axis limits for axis_2 (if necessary)
# axis_2.set_ylim(0, df_unemployment['UNRATE'].max() + 5)  # Adjust the maximum value if needed

# Set labels and title
axis_1.set_xlabel('Year', fontsize=14)
axis_1.set_ylabel('FRED U/E rate', fontsize=14 , color='purple')
axis_2.set_ylabel('Unemployment rate', color='r', fontsize=14)

# Add a title to the plot
plt.title("Rolling monthly US 'unemployement benefit' web search v.s. Unemployment rate", fontsize=16)


import matplotlib.dates as mdates 

years = mdates.YearLocator()
months = mdates.MonthLocator()
years_fmt = mdates.DateFormatter('%Y')

# format the 
axis_1.xaxis.set_major_locator(years)
axis_1.xaxis.set_major_formatter(years_fmt)
axis_1.xaxis.set_minor_locator(months)

# %% [markdown]
# ### Including 2020 in Unemployment Charts

# %% [markdown]
# **Challenge**: Read the data in the 'UE Benefits Search vs UE Rate 2004-20.csv' into a DataFrame. Convert the MONTH column to Pandas Datetime objects and then plot the chart. What do you see?

# %%
import matplotlib.pyplot as plt

# Create a figure with a specified DPI
plt.figure(figsize=(10, 5) )  # Width=10 inches, Height=5 inches, DPI=100

plt.grid()
# Used to get the current axis
axis_1 = plt.gca()

# Set the x-axis tick labels with rotation
plt.xticks(rotation=45)

# Used to share the same x-axis but y-axis on different side
axis_2 = plt.twinx()

# Calculate the rolling average over a 6 month window
roll_df = df_unemployment_new[['UE_BENEFITS_WEB_SEARCH', 'UNRATE']].rolling(window=6).mean()

# Your data and plotting code
axis_1.plot(df_unemployment_new['MONTH'], roll_df['UE_BENEFITS_WEB_SEARCH'], color='purple', linewidth=2 , )
axis_2.plot(df_unemployment_new['MONTH'], roll_df['UNRATE'], 'r', linewidth=2 ,linestyle = 'dashed' )

# Set the x-axis limits
axis_1.set_xlim([df_unemployment_new['MONTH'].min(), df_unemployment_new['MONTH'].max()])  # Set x-axis limits based on data

# Set labels and title
axis_1.set_xlabel('Year', fontsize=14)
axis_1.set_ylabel('FRED U/E rate', fontsize=14 , color='purple')
axis_2.set_ylabel('Unemployment rate', color='r', fontsize=14)

# Add a title to the plot
plt.title("Rolling monthly US 'unemployement benefit' web search v.s. Unemployment rate", fontsize=16)


import matplotlib.dates as mdates 

years = mdates.YearLocator()
months = mdates.MonthLocator()
years_fmt = mdates.DateFormatter('%Y')

# format the 
axis_1.xaxis.set_major_locator(years)
axis_1.xaxis.set_major_formatter(years_fmt)
axis_1.xaxis.set_minor_locator(months)

# %%
world_unemployment_rate = pd.read_csv('unemployment analysis.csv')

# %%
world_unemployment_rate.head()
# Out:
#                   Country Name Country Code   1991   1992   1993   1994  \
# 0  Africa Eastern and Southern          AFE   7.80   7.84   7.85   7.84
# 1                  Afghanistan          AFG  10.65  10.82  10.72  10.73
# 2   Africa Western and Central          AFW   4.42   4.53   4.55   4.54
# 3                       Angola          AGO   4.21   4.21   4.23   4.16
# 4                      Albania          ALB  10.31  30.01  25.26  20.84
#
#     1995   1996   1997   1998  ...   2012   2013   2014   2015   2016   2017  \
# 0   7.83   7.84   7.86   7.81  ...   6.56   6.45   6.41   6.49   6.61   6.71
# 1  11.18  10.96  10.78  10.80  ...  11.34  11.19  11.14  11.13  11.16  11.18
# 2   4.53   4.57   4.60   4.66  ...   4.64   4.41   4.69   4.63   5.57   6.02
# 3   4.11   4.10   4.09   4.07  ...   7.35   7.37   7.37   7.39   7.41   7.41
# 4  14.61  13.93  16.88  20.05  ...  13.38  15.87  18.05  17.19  15.42  13.62
#
#     2018   2019   2020   2021
# 0   6.73   6.91   7.56   8.11
# 1  11.15  11.22  11.71  13.28
# 2   6.04   6.06   6.77   6.84
# 3   7.42   7.42   8.33   8.53
# 4  12.30  11.47  13.33  11.82
#
# [5 rows x 33 columns]

# %%
world_unemployment_rate.columns[2:]
# world_unemployment_rate[world_unemployment_rate['Country Name']=="India"].iloc[:, 2:]
# Out:
# Index(['1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999',
#        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#        '2018', '2019', '2020', '2021'],
#       dtype='object')

# %%
plt.plot( world_unemployment_rate[world_unemployment_rate['Country Name']=="India"].iloc[:, 2:])
# Out:
# [<matplotlib.lines.Line2D at 0x19e4f45ee70>,
#  <matplotlib.lines.Line2D at 0x19e4ec3f0e0>,
#  <matplotlib.lines.Line2D at 0x19e4f45d640>,
#  <matplotlib.lines.Line2D at 0x19e4f45fa40>,
#  <matplotlib.lines.Line2D at 0x19e4f45e060>,
#  <matplotlib.lines.Line2D at 0x19e4f45dd90>,
#  <matplotlib.lines.Line2D at 0x19e4f45dd00>,
#  <matplotlib.lines.Line2D at 0x19e4f45deb0>,
#  <matplotlib.lines.Line2D at 0x19e4f45d4c0>,
#  <matplotlib.lines.Line2D at 0x19e4f096600>,
#  <matplotlib.lines.Line2D at 0x19e4e3b9010>,
#  <matplotlib.lines.Line2D at 0x19e4f45e270>,
#  <matplotlib.lines.Line2D at 0x19e4f45cd10>,
#  <matplotlib.lines.Line2D at 0x19e4f45cd70>,
#  <matplotlib.lines.Line2D at 0x19e4f0c43e0>,
#  <matplotlib.lines.Line2D at 0x19e4f4b4290>,
#  <matplotlib.lines.Line2D at 0x19e4f3fb9b0>,
#  <matplotlib.lines.Line2D at 0x19e4f3fb8f0>,
#  <matplotlib.lines.Line2D at 0x19e4f3fa810>,
#  <matplotlib.lines.Line2D at 0x19e4f3fb2c0>,
#  <matplotlib.lines.Line2D at 0x19e4f3f8560>,
#  <matplotlib.lines.Line2D at 0x19e4f3f9dc0>,
#  <matplotlib.lines.Line2D at 0x19e4bfb4320>,
#  <matplotlib.lines.Line2D at 0x19e4f3fbf20>,
#  <matplotlib.lines.Line2D at 0x19e4f3faf60>,
#  <matplotlib.lines.Line2D at 0x19e4e10e720>,
#  <matplotlib.lines.Line2D at 0x19e4f3fbe90>,
#  <matplotlib.lines.Line2D at 0x19e4f3fa7e0>,
#  <matplotlib.lines.Line2D at 0x19e4f3fb620>,
#  <matplotlib.lines.Line2D at 0x19e4bfb6ae0>,
#  <matplotlib.lines.Line2D at 0x19e4f3f82c0>]
